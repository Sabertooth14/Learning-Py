# %%
import requests

# %%
get_req = requests.get("https://www.beamsuntory.com/en")

# %%
get_req.text
# Out:
# '<!doctype html>\n<html itemscope itemtype="http://schema.org/" lang="en-us" class="locale-en-us">\n<head>\n            <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">\n\t<script src="https://cdnjs.cloudflare.com/ajax/libs/babel-core/5.6.15/browser-polyfill.min.js"></script>\n        <meta charset="UTF-8"/>\n        <meta http-equiv="x-ua-compatible" content="ie=edge"/>\n        <meta http-equiv="x-dns-prefetch-control" content="on"/>\n                    <title>Beam Suntory | Global Premium Spirits</title>\n            <meta name="title" content="Beam Suntory | Global Premium Spirits"/>\n                            <meta name="description" content="Beam Suntory is a world leader in premium spirits with a mission of inspiring human connections. Learn more about how we Unleash Our Spirit and Grow for Good."/>\n                            <meta name="keywords" content="Wine &amp; spirits, liquor brands, beverage industry, premium spirits, spirits 
# ...

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(get_req.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="locale-en-us" itemscope="" itemtype="http://schema.org/" lang="en-us">
# <head>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/babel-core/5.6.15/browser-polyfill.min.js"></script>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <title>Beam Suntory | Global Premium Spirits</title>
# <meta content="Beam Suntory | Global Premium Spirits" name="title"/>
# <meta content="Beam Suntory is a world leader in premium spirits with a mission of inspiring human connections. Learn more about how we Unleash Our Spirit and Grow for Good." name="description"/>
# <meta content="Wine &amp; spirits, liquor brands, beverage industry, premium spirits, spirits brands" name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
soup.select('title')
# Out:
# [<title>Beam Suntory | Global Premium Spirits</title>]

# %%
soup.select('title')[0].getText()
# Out:
# 'Beam Suntory | Global Premium Spirits'

# %%
soup.select('p')[0].text
# Out:
# "As a world leader in premium spirits, Beam Suntory is inspiring human connections. With a performance objective of being the world’s most admired and fastest growing premium spirits company, and a vision of Growing for Good, we're driving growth through quality craftsmanship, consumer connections and entrepreneurial spirit.\r\n\n                \n"

# %%
res = requests.get("https://en.wikipedia.org/wiki/Ratan_Tata")

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Ratan Tata - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"904580f2-e297-46e3-b69b-b463ef78b181","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Ratan_Tata","wgTitle":"Ratan Tata","wgCurRevisionId":1064237172,"wgRevisionId":1064237172,"wgArticleId":1137487,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 errors: missing periodical","All articles with dead external links","Articles with dead external links from June 2020","Articles with permanently dead
# ...

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Ratan Tata - Wikipedia</title>
# ...

# %%
soup.select('.toctext')
# Out:
# [<span class="toctext">Early life</span>,
#  <span class="toctext">Tata Sons vs. Cyrus Mistry</span>,
#  <span class="toctext">Philanthropy</span>,
#  <span class="toctext">Board memberships and affiliations</span>,
#  <span class="toctext">Honours and awards</span>,
#  <span class="toctext">Personal life</span>,
#  <span class="toctext">In popular culture</span>,
#  <span class="toctext">References</span>,
#  <span class="toctext">Bibliography</span>,
#  <span class="toctext">External links</span>]

# %%
for i in soup.select('.toctext'):
    print(i.text)
# Out:
# Early life
# Tata Sons vs. Cyrus Mistry
# Philanthropy
# Board memberships and affiliations
# Honours and awards
# Personal life
# In popular culture
# References
# Bibliography
# External links

# %%
for i in soup.select('#contentSub'):
    print(i.text)

# %%
soup.select('#contentSub')
# Out:
# [<div id="contentSub"></div>]

# %%
soup.select('div span')
# Out:
# [<span style="display:none"> (<span class="bday">1937-12-28</span>) </span>,
#  <span class="bday">1937-12-28</span>,
#  <span class="noprint ForceAgeToShow"> (age 84)</span>,
#  <span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span>,
#  <span class="tocnumber">1</span>,
#  <span class="toctext">Early life</span>,
#  <span class="tocnumber">1.1</span>,
#  <span class="toctext">Tata Sons vs. Cyrus Mistry</span>,
#  <span class="tocnumber">2</span>,
#  <span class="toctext">Philanthropy</span>,
#  <span class="tocnumber">3</span>,
#  <span class="toctext">Board memberships and affiliations</span>,
#  <span class="tocnumber">4</span>,
#  <span class="toctext">Honours and awards</span>,
#  <span class="tocnumber">5</span>,
#  <span class="toctext">Personal life</span>,
#  <span class="tocnumber">6</span>,
#  <span class="toctext">In popular culture</span>,
#  <span class="tocnumber">7</span>,
#  <span class="toctext">References</span>,
# ...

# %%
soup.select('div>span')[1].text
# Out:
# 'Edit links'

# %%
soup.select('.thumbimage')
# Out:
# [<img alt="" class="thumbimage" data-file-height="159" data-file-width="216" decoding="async" height="159" src="//upload.wikimedia.org/wikipedia/commons/1/11/Ratan_Tata.jpg" width="216"/>,
# ...

# %%
image = soup.select('.thumbimage')[1]

# %%
image['src'].
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/The_President%2C_Smt._Pratibha_Devisingh_Patil_presenting_the_Padma_Vibhushan_to_Shri_Ratan_Naval_Tata_at_Civil_Investiture-II_Ceremony%2C_at_Rashtrapati_Bhavan%2C_in_New_Delhi_on_May_10%2C_2008.jpg/220px-thumbnail.jpg'

# %%
link =requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/The_President%2C_Smt._Pratibha_Devisingh_Patil_presenting_the_Padma_Vibhushan_to_Shri_Ratan_Naval_Tata_at_Civil_Investiture-II_Ceremony%2C_at_Rashtrapati_Bhavan%2C_in_New_Delhi_on_May_10%2C_2008.jpg/220px-thumbnail.jpg')

# %%
link.content
# Out:
# b'\xff\xd8\xff\xe1\x01\x8eExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x07\x01\x0e\x00\x02\x00\x00\x00\xbc\x00\x00\x00b\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x01\x1e\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x01&\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x01;\x00\x02\x00\x00\x00\n\x00\x00\x01.\x02\x13\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x82\x98\x00\x02\x00\x00\x00M\x00\x00\x018\x00\x00\x00\x00The President, Smt. Pratibha Devisingh Patil presenting the Padma Vibhushan to Shri Ratan Naval Tata at Civil Investiture-II Ceremony, at Rashtrapati Bhavan, in New Delhi on May 10, 2008.\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x01M.Shankar\x00Photo Division, Ministry of Information & Broadcasting, Government of India.\x00\x00\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\
# ...

# %%
f = open('practice_img.jpg','wb')

# %%
f.write(link.content)
# Out:
# 13137

# %%
f.close()

# %% [markdown]
# <img
#      src = "//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/The_President%2C_Smt._Pratibha_Devisingh_Patil_presenting_the_Padma_Vibhushan_to_Shri_Ratan_Naval_Tata_at_Civil_Investiture-II_Ceremony%2C_at_Rashtrapati_Bhavan%2C_in_New_Delhi_on_May_10%2C_2008.jpg/220px-thumbnail.jpg">
