# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('TopDistributors.csv')

# %%
df
# Out:
#    RANK        DISTRIBUTORS  MOVIES      TOTAL GROSS AVERAGE GROSS  \
# 0     1         Walt Disney     588  $40,472,424,278   $68,830,654
# 1     2        Warner Bros.     824  $36,269,425,479   $44,016,293
# 2     3       Sony Pictures     747  $29,113,002,302   $38,973,229
# 3     4           Universal     535  $28,089,932,569   $52,504,547
# 4     5    20th Century Fox     525  $25,857,839,756   $49,253,028
# 5     6  Paramount Pictures     493  $24,361,425,304   $49,414,656
# 6     7           Lionsgate     426   $9,631,837,781   $22,609,948
# 7     8            New Line     209   $6,195,268,024   $29,642,431
# 8     9      Dreamworks SKG      77   $4,278,649,271   $55,566,874
# 9    10             Miramax     385   $3,836,019,208    $9,963,686
#
#   MARKET SHARE
# 0       17.02%
# 1       15.25%
# 2       12.24%
# 3       11.81%
# 4       10.88%
# 5       10.25%
# 6        4.05%
# 7        2.61%
# 8        1.80%
# 9        1.61%

# %%
df.describe()
# Out:
#            RANK      MOVIES
# count  10.00000   10.000000
# mean    5.50000  480.900000
# std     3.02765  224.670351
# min     1.00000   77.000000
# 25%     3.25000  395.250000
# 50%     5.50000  509.000000
# 75%     7.75000  574.750000
# max    10.00000  824.000000

# %%
df.loc[3,'DISTRIBUTORS']
# Out:
# 'Universal'

# %%
df['AVERAGE GROSS']
# Out:
# 0    $68,830,654
# 1    $44,016,293
# 2    $38,973,229
# 3    $52,504,547
# 4    $49,253,028
# 5    $49,414,656
# 6    $22,609,948
# 7    $29,642,431
# 8    $55,566,874
# 9     $9,963,686
# Name: AVERAGE GROSS, dtype: object

# %%
df.dtypes
# Out:
# RANK              int64
# DISTRIBUTORS     object
# MOVIES            int64
# TOTAL GROSS      object
# AVERAGE GROSS    object
# MARKET SHARE     object
# dtype: object

# %%
df.loc[5,'MARKET SHARE']= '10.30%'

# %%
df
# Out:
#    RANK        DISTRIBUTORS  MOVIES      TOTAL GROSS AVERAGE GROSS  \
# 0     1         Walt Disney     588  $40,472,424,278   $68,830,654
# 1     2        Warner Bros.     824  $36,269,425,479   $44,016,293
# 2     3       Sony Pictures     747  $29,113,002,302   $38,973,229
# 3     4           Universal     535  $28,089,932,569   $52,504,547
# 4     5    20th Century Fox     525  $25,857,839,756   $49,253,028
# 5     6  Paramount Pictures     493  $24,361,425,304   $49,414,656
# 6     7           Lionsgate     426   $9,631,837,781   $22,609,948
# 7     8            New Line     209   $6,195,268,024   $29,642,431
# 8     9      Dreamworks SKG      77   $4,278,649,271   $55,566,874
# 9    10             Miramax     385   $3,836,019,208    $9,963,686
#
#   MARKET SHARE
# 0       17.02%
# 1       15.25%
# 2       12.24%
# 3       11.81%
# 4       10.88%
# 5       10.30%
# 6        4.05%
# 7        2.61%
# 8        1.80%
# 9        1.61%

# %%
df.loc[(df['MOVIES']>500)]
# Out:
#    RANK      DISTRIBUTORS  MOVIES      TOTAL GROSS AVERAGE GROSS MARKET SHARE
# 0     1       Walt Disney     588  $40,472,424,278   $68,830,654       17.02%
# 1     2      Warner Bros.     824  $36,269,425,479   $44,016,293       15.25%
# 2     3     Sony Pictures     747  $29,113,002,302   $38,973,229       12.24%
# 3     4         Universal     535  $28,089,932,569   $52,504,547       11.81%
# 4     5  20th Century Fox     525  $25,857,839,756   $49,253,028       10.88%

# %%
df.loc[[3,7],['AVERAGE GROSS','MARKET SHARE']]
# Out:
#   AVERAGE GROSS MARKET SHARE
# 3   $52,504,547       11.81%
# 7   $29,642,431        2.61%

# %%
 del df[('RANK')]

# %%
df
# Out:
#          DISTRIBUTORS  MOVIES      TOTAL GROSS AVERAGE GROSS MARKET SHARE
# 0         Walt Disney     588  $40,472,424,278   $68,830,654       17.02%
# 1        Warner Bros.     824  $36,269,425,479   $44,016,293       15.25%
# 2       Sony Pictures     747  $29,113,002,302   $38,973,229       12.24%
# 3           Universal     535  $28,089,932,569   $52,504,547       11.81%
# 4    20th Century Fox     525  $25,857,839,756   $49,253,028       10.88%
# 5  Paramount Pictures     493  $24,361,425,304   $49,414,656       10.30%
# 6           Lionsgate     426   $9,631,837,781   $22,609,948        4.05%
# 7            New Line     209   $6,195,268,024   $29,642,431        2.61%
# 8      Dreamworks SKG      77   $4,278,649,271   $55,566,874        1.80%
# 9             Miramax     385   $3,836,019,208    $9,963,686        1.61%

# %%
df.sort_values(by=['MOVIES'],ascending=False)
# Out:
#          DISTRIBUTORS  MOVIES      TOTAL GROSS AVERAGE GROSS MARKET SHARE
# 1        Warner Bros.     824  $36,269,425,479   $44,016,293       15.25%
# 2       Sony Pictures     747  $29,113,002,302   $38,973,229       12.24%
# 0         Walt Disney     588  $40,472,424,278   $68,830,654       17.02%
# 3           Universal     535  $28,089,932,569   $52,504,547       11.81%
# 4    20th Century Fox     525  $25,857,839,756   $49,253,028       10.88%
# 5  Paramount Pictures     493  $24,361,425,304   $49,414,656       10.30%
# 6           Lionsgate     426   $9,631,837,781   $22,609,948        4.05%
# 9             Miramax     385   $3,836,019,208    $9,963,686        1.61%
# 7            New Line     209   $6,195,268,024   $29,642,431        2.61%
# 8      Dreamworks SKG      77   $4,278,649,271   $55,566,874        1.80%

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#          DISTRIBUTORS  MOVIES      TOTAL GROSS AVERAGE GROSS MARKET SHARE
# 9             Miramax     385   $3,836,019,208    $9,963,686        1.61%
# 8      Dreamworks SKG      77   $4,278,649,271   $55,566,874        1.80%
# 7            New Line     209   $6,195,268,024   $29,642,431        2.61%
# 6           Lionsgate     426   $9,631,837,781   $22,609,948        4.05%
# 5  Paramount Pictures     493  $24,361,425,304   $49,414,656       10.30%
# 4    20th Century Fox     525  $25,857,839,756   $49,253,028       10.88%
# 3           Universal     535  $28,089,932,569   $52,504,547       11.81%
# 2       Sony Pictures     747  $29,113,002,302   $38,973,229       12.24%
# 1        Warner Bros.     824  $36,269,425,479   $44,016,293       15.25%
# 0         Walt Disney     588  $40,472,424,278   $68,830,654       17.02%

# %%
df.to_numpy()
# Out:
# array([['Walt Disney', 588, '$40,472,424,278', '$68,830,654', '17.02%'],
#        ['Warner Bros.', 824, '$36,269,425,479', '$44,016,293', '15.25%'],
#        ['Sony Pictures', 747, '$29,113,002,302', '$38,973,229', '12.24%'],
#        ['Universal', 535, '$28,089,932,569', '$52,504,547', '11.81%'],
#        ['20th Century Fox', 525, '$25,857,839,756', '$49,253,028',
#         '10.88%'],
#        ['Paramount Pictures', 493, '$24,361,425,304', '$49,414,656',
#         '10.30%'],
#        ['Lionsgate', 426, '$9,631,837,781', '$22,609,948', '4.05%'],
#        ['New Line', 209, '$6,195,268,024', '$29,642,431', '2.61%'],
#        ['Dreamworks SKG', 77, '$4,278,649,271', '$55,566,874', '1.80%'],
#        ['Miramax', 385, '$3,836,019,208', '$9,963,686', '1.61%']],
#       dtype=object)

# %%
df.DISTRIBUTORS
# Out:
# 0           Walt Disney
# 1          Warner Bros.
# 2         Sony Pictures
# 3             Universal
# 4      20th Century Fox
# 5    Paramount Pictures
# 6             Lionsgate
# 7              New Line
# 8        Dreamworks SKG
# 9               Miramax
# Name: DISTRIBUTORS, dtype: object

# %%
 import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,8))
plt.plot(df.DISTRIBUTORS,df['TOTAL GROSS'])
